# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.optimize import minimize

# %% [markdown]
# minimize f(x) = x^3 + y^3 - 3xy
#
#         3x+y  <= 3
#         5x-3y <= 5
#         x,y   >= 0

# %%
f = lambda x: x[0]**3 + x[1]**3 - 3*x[0]*x[1]
cons = ({'type':'ineq','fun': lambda x: -3*x[0]-x[1]+3},
        {'type':'ineq','fun': lambda x: -5*x[0]+3*x[1]+5})

bnds = ((0,None),(0,None))

X0 = (2,0)
res = minimize(f,X0, bounds=bnds, constraints= cons)
res2 = minimize(f,X0)
res2
res
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -0.8536512957888381
#        x: [ 7.325e-01  8.024e-01]
#      nit: 7
#      jac: [-7.975e-01 -2.659e-01]
#     nfev: 22
#     njev: 7

# %%
res2
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: -0.9999999999998475
#         x: [ 1.000e+00  1.000e+00]
#       nit: 7
#       jac: [-1.237e-06  1.088e-06]
#  hess_inv: [[ 2.205e-01  1.126e-01]
#             [ 1.126e-01  2.214e-01]]
#      nfev: 27
#      njev: 9

# %%
res3 = minimize(f,X0)
res3
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: -0.9999999999998475
#         x: [ 1.000e+00  1.000e+00]
#       nit: 7
#       jac: [-1.237e-06  1.088e-06]
#  hess_inv: [[ 2.205e-01  1.126e-01]
#             [ 1.126e-01  2.214e-01]]
#      nfev: 27
#      njev: 9

# %%
from mpl_toolkits.mplot3d import Axes3D

f = lambda x0, x1: x0**3 + x1**3 - 3*x0*x1
x1 = np.linspace(-1.5,1.5,100)
x0 = np.linspace(-1,5,100)

X, Y = np.meshgrid(x0,x1)
F = f(X,Y)

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(1,2,1,projection='3d')
ax.scatter3D(1,1,f(1,1),c="black",marker="*",s=100)
surf = ax.plot_surface(X,Y,F, cmap= 'gist_rainbow')

ax.set_xlabel('x0', labelpad=10)
ax.set_ylabel('x1', labelpad=30)
ax.set_zlabel('f(X)', labelpad=10)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

f = lambda x0, x1: x0**3 + x1**3 - 3*x0*x1
x1 = np.linspace(-1.5,1.5,100)
x0 = np.linspace(-1,5,100)

X, Y = np.meshgrid(x0,x1)
F = f(X,Y)

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(1,2,1,projection='3d') # set up the axis as a 3D plot
ax.scatter3D(1,1,f(1,1),c="black",marker="*",s=100)
surf = ax.plot_surface(X,Y,F, cmap= 'gist_rainbow')
ax1 = plt.subplot(1,2,2,projection='3d')
ax1.scatter3D(1,1,f(1,1),c="black",marker="*",s=100)
con = ax1.contour(X,Y,F, cmap= 'gist_rainbow')
fig.colorbar(surf,shrink=0.4, aspect=10)
# set axes label
ax.set_xlabel('x0', labelpad=10)
ax.set_ylabel('x1', labelpad=30)
ax.set_zlabel('f(X)', labelpad=10)

plt.show()

# %%
x = np.linspace(1,4,100)
y = np.linspace(2,5,100)
X, Y = np.meshgrid(x,y)
Z = f(np.vstack([X.ravel(), Y.ravel()])).reshape((100,100))

fig = plt.figure(figsize=(6,7))

levels = np.arange(0.0,12,0.4)
cp = plt.contour(X,Y,Z,levels=levels , cmap='gist_rainbow')
plt.clabel(cp)
plt.plot(x,(x+2/2),'k:', linewidth=1)
plt.plot(res.x[0],res.x[1],c='r',marker='o')
plt.plot(res2.x[0],res2.x[1],c='b',marker='x')
plt.plot(res3.x[0],res3.x[1],c='g',marker='*',markersize=10)
plt.plot(x, (-x+6)/2, 'k:', linewidth=1)
plt.axis([1,6,2,6])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot?
